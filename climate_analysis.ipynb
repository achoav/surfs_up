# %%
# 9.1.3. Import Matplotlib Dependencies 
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
# 9.1.3. Import Numpy and Pandas Dependencies
import numpy as np
import pandas as pd

# %%
# 9.1.3. Import Datetime Dependencies ###
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# 9.1.3. Import Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# 9.1.4. QLAlchemy Create Engine. Database setup
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# 9.1.4. SQLAlchemy Automap Base . reflect an existing database into a new model
Base = automap_base()

# %%
# 9.1.4. SQLAlchemy Reflect tables
Base.prepare(engine, reflect=True)

# %%
# 9.1.4. We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# 9.1.4. Save references to each table: 'Measurement' and 'Station'. 
# Base.classes.<class name>
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# 9.1.4. Create our session (link) from Python to the DB
session = Session(engine)

# %%
dummy = session.query(Measurement).first()
dummy.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x2d663cdd580>,
#  'date': '2010-01-01',
#  'id': 1,
#  'prcp': 0.08,
#  'station': 'USC00519397',
#  'tobs': 65.0}

# %%
# query date and preciptation columns
results = session.query(Measurement.date, Measurement.prcp).all()

# %%
# print out results by looping the results
for results in results:
 print(results)
# Out:
# ('2010-01-01', 0.08)
# ('2010-01-02', 0.0)
# ('2010-01-03', 0.0)
# ('2010-01-04', 0.0)
# ('2010-01-06', None)
# ('2010-01-07', 0.06)
# ('2010-01-08', 0.0)
# ('2010-01-09', 0.0)
# ('2010-01-10', 0.0)
# ('2010-01-11', 0.01)
# ('2010-01-12', 0.0)
# ('2010-01-14', 0.0)
# ('2010-01-15', 0.0)
# ('2010-01-16', 0.0)
# ('2010-01-17', 0.0)
# ('2010-01-18', 0.0)
# ('2010-01-19', 0.0)
# ('2010-01-20', 0.0)
# ('2010-01-21', 0.0)
# ('2010-01-22', 0.0)
# ('2010-01-23', 0.0)
# ('2010-01-24', 0.01)
# ('2010-01-25', 0.0)
# ('2010-01-26', 0.04)
# ('2010-01-27', 0.12)
# ('2010-01-28', 0.0)
# ('2010-01-30', None)
# ('2010-01-31', 0.03)
# ('2010-02-01', 0.01)
# ('2010-02-03', None)
# ('2010-02-04', 0.01)
# ('2010-02-05', 0.0)
# ('2010-02-06', 0.0)
# ('2010-02-07', 0.0)
# ('2010-02-08', 0.0)
# ('2010-02-09', 0.0)
# ('2010-02-11', 0.0)
# ('2010-02-12', 0.02)
# ('2010-02-13', 0.01)
# ('2010-02-14', 0.0)
# ('2010-02-15', 0.0)
# ('2010-02-16', 0.0)
# ('2010-02-17', 0.0)
# ('2010-02-19', None)
# ...

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# 9.2.1. Design a query to retrieve the last 12 months of precipitation data and plot the results. 
#Starting from the last data point in the database. 
prev_year = dt.date(2017, 8, 23)

# 9.2.1. Calculate the date one year from the last date in data set. 365 days.
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)

# 9.2.1. Create a variable to store the results of the query we'll write
results = []

# 9.2.1. Perform a query to retrieve the data and precipitation scores
results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year)
#print(results.all())

# 9.2.2. Save the Query Results as a Pandas DataFrame and set the index to the date column
# This saves our query in two columns 'date' and 'precipitation'
df = pd.DataFrame(results, columns=['date','precipitation'])

# 9.2.2. Use the set_index() Func
df.set_index(df['date'], inplace=True)
df = df.sort_index()
#print(df.to_string(index=False))

# 9.2.4. PLot the Data
df.plot(figsize=(18,4));
plt.savefig("Images/Precipitation Analysis.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Write a function calc_temps that will accept a start date and end date in the format %Y-%m-%d and 
# return the minimum, average, and maximum temperatures for that range of dates.
class Temp():
    def __init__(self, minimum, average, maximum):
        self.minimum = minimum
        self.average = average
        self.maximum = maximum
        
def calc_temps(start_date, end_date):
    minimum = session.query(func.min(Measurement.tobs)).filter(Measurement.date.between(start_date, end_date)).scalar()
    print(f"Minimum temp: {minimum}")
    average = session.query(func.round(func.avg(Measurement.tobs))).filter(Measurement.date.between(start_date, end_date)).scalar()
    print(f"Average temp: {average}")
    maximum = session.query(func.max(Measurement.tobs)).filter(Measurement.date.between(start_date, end_date)).scalar()
    print(f"Maximum temp: {maximum}")
    
    result = [{"Minimum":minimum},{"Maximum":maximum},{"Average":average}]
    result = Temp(minimum, average, maximum)
    return result    

t = calc_temps('2017-07-01','2017-07-15')
t.minimum, t.average, t.maximum

# Save an image of the chart and print the scree
plt.savefig("Images/Precipitation Analysis.png")
plt.show()
# Out:
# Minimum temp: 69.0
# Average temp: 78.0
# Maximum temp: 87.0

# %% [markdown]
# 9.2.5 Generate the Summary of Statistics

# %%
# 9.2.5. Use Pandas to calcualte the summary statistics for the precipitation data
df.describe()
# Out:
#        precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
# 9.2.5. How many stations are being used to collect the data in this dataset?
session.query(func.count(Station.station)).all()
# Now we know there are 9 stations from which precipitation data is being collected
# Out:
# [(9)]

# %% [markdown]
# 9.3.2 Determine the Most Active Stations

# %%
# 9.3.2. What are the most active stations?
session.query(Measurement.station, func.count(Measurement.station)).\
    group_by(Measurement.station)
# 9.3.2. List the stations and the counts in descending order.
session.query(Measurement.station, func.count(Measurement.station)).\
group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %% [markdown]
# 9.3.3. Find Low, High, and Average Temperatures

# %%
# 9.3.3. Using the station id from the previous query, calculate the MIN, MAX, AVERAGE temperature recorded, 
result = session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
filter(Measurement.station == 'USC00519281').all()

# highest temperature recorded, and average temperature most active station?
# The results show that the low (minimum) temperature is 54 degree
# the high (maximum) temperature is 85 degrees
# and the average temperature is approximately 71.7 degrees.
result
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Minimum Temperature
print(result[0][0])
# Out:
# 54.0

# %%
# Maximum Temperature
print(result[0][1])
# Out:
# 85.0

# %%
# Average Temperature
print(result[0][2])
# Out:
# 71.66378066378067

# %% [markdown]
# 9.3.4. Plot the Highest Number of Observations

# %%
# 9.3.4. Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station 
results = session.query(Measurement.tobs).\
filter(Measurement.station == 'USC00519281').\
filter(Measurement.date >= prev_year).all()
# print(results)
# Convert the Temperature Observation Results to a DataFrame# 
df = pd.DataFrame(results, columns=['tobs'])
print(df)
# Out:
#      tobs
# 0    77.0
# 1    77.0
# 2    80.0
# 3    80.0
# 4    75.0
# ..    ...
# 347  77.0
# 348  77.0
# 349  76.0
# 350  76.0
# 351  79.0
#
# [352 rows x 1 columns]

# %%
# 9.3.4. Plot the Temperature Observations
# Looking at this plot, we can infer that a vast majority of the observations were over 67 degrees
df.plot.hist(bins=12)
plt.tight_layout()

# %% [markdown]
# 9.4.3. Building Flask Routes

# %%
# Import Flask dependency
# See Visual Basic File

# %%
def calc_temps(start_date,end_date):
    result = session.query(func.min(Measurement.tobs),func.max(Measurement.tobs),func.avg(Measurment.tools)).\
    filter(Measurement.date >= start_date).\
    filter(Measurement.date >= end_date).all()
    return result[1]

results = session.query(Measurement.tobs).\
filter(Measurement.station == 'USC0519281').\
filter(Measurement.date >= prev_year).all()

df = pd.DataFrame(results,columns=['tobs'])
df
# Out:
# Empty DataFrame
# Columns: [tobs]
# Index: []

# %% [markdown]
# # Challenge
